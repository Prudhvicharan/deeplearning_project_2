# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from tabulate import tabulate

# Install required libraries
# !pip install -U portalocker>=2.0.0
# !pip install tabulate

# Define data transformation
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# Load FashionMNIST dataset
train_dataset = torchvision.datasets.FashionMNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = torchvision.datasets.FashionMNIST(root='./data', train=False, download=True, transform=transform)

# Create data loaders
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=64, shuffle=False)

# Labels mapping
labels_map = {
    0: "T-shirt/top", 1: "Trouser", 2: "Pullover", 3: "Dress", 4: "Coat",
    5: "Sandal", 6: "Shirt", 7: "Sneaker", 8: "Bag", 9: "Ankle boot"
}

# Display sample images
def display_sample_images():
    figure = plt.figure(figsize=(8, 8))
    cols, rows = 3, 3

    for i in range(1, cols * rows + 1):
        sample_idx = torch.randint(len(train_dataset), size=(1,)).item()
        img, label = train_dataset[sample_idx]
        figure.add_subplot(rows, cols, i)
        plt.title(labels_map[label])
        plt.axis("off")
        plt.imshow(img.squeeze(), cmap="gray")
    plt.show()

# Model definition
class FashionMLP(nn.Module):
    def __init__(self, num_hidden_layers, hidden_layer_sizes):
        super(FashionMLP, self).__init__()
        layers = []
        layers.append(nn.Linear(28 * 28, hidden_layer_sizes[0]))  # Input layer
        for i in range(num_hidden_layers - 1):  # Hidden layers
            layers.append(nn.Linear(hidden_layer_sizes[i], hidden_layer_sizes[i + 1]))
        layers.append(nn.Linear(hidden_layer_sizes[-1], 10))  # Output layer
        self.layers = nn.ModuleList(layers)

    def forward(self, x):
        x = x.view(-1, 28 * 28)
        for layer in self.layers[:-1]:
            x = torch.sigmoid(layer(x))
        x = self.layers[-1](x)
        return x

# Define configurations
configurations = [
    {
        'name': "Configuration-1",
        'num_hidden_layers': 3,
        'hidden_layer_sizes': [32, 64, 128],
        'batch_size': 64,
        'learning_rate': 0.001,
        'optimizer': optim.Adam
    },
    {
        'name': "Configuration-2",
        'num_hidden_layers': 3,
        'hidden_layer_sizes': [64, 128, 256],
        'batch_size': 512,
        'learning_rate': 0.001,
        'optimizer': optim.RMSprop
    },
    {
        'name': "Configuration-3",
        'num_hidden_layers': 3,
        'hidden_layer_sizes': [128, 256, 512],
        'batch_size': 64,
        'learning_rate': 0.001,
        'optimizer': optim.Adam
    },
    {
        'name': "Configuration-4",
        'num_hidden_layers': 2,
        'hidden_layer_sizes': [64, 128],
        'batch_size': 64,
        'learning_rate': 0.001,
        'optimizer': optim.Adam
    },
    {
        'name': "Configuration-5",
        'num_hidden_layers': 2,
        'hidden_layer_sizes': [32, 64],
        'batch_size': 64,
        'learning_rate': 0.001,
        'optimizer': optim.Adam
    },
    {
        'name': "Configuration-6",
        'num_hidden_layers': 2,
        'hidden_layer_sizes': [128, 256],
        'batch_size': 64,
        'learning_rate': 0.001,
        'optimizer': optim.Adam
    },
    {
        'name': "Configuration-7",
        'num_hidden_layers': 2,
        'hidden_layer_sizes': [256, 512],
        'batch_size': 64,
        'learning_rate': 0.001,
        'optimizer': optim.RMSprop
    },
    {
        'name': "Configuration-8",
        'num_hidden_layers': 1,
        'hidden_layer_sizes': [64],
        'batch_size': 64,
        'learning_rate': 0.001,
        'optimizer': optim.Adam
    },
    {
        'name': "Configuration-9",
        'num_hidden_layers': 1,
        'hidden_layer_sizes': [128],
        'batch_size': 64,
        'learning_rate': 0.001,
        'optimizer': optim.Adam
    },
    {
        'name': "Configuration-10",
        'num_hidden_layers': 1,
        'hidden_layer_sizes': [256],
        'batch_size': 64,
        'learning_rate': 0.001,
        'optimizer': optim.Adam
    },
    {
        'name': "Configuration-11",
        'num_hidden_layers': 3,
        'hidden_layer_sizes': [32, 64, 128],
        'batch_size': 128,
        'learning_rate': 0.001,
        'optimizer': optim.RMSprop
    },
    {
        'name': "Configuration-12",
        'num_hidden_layers': 4,
        'hidden_layer_sizes': [64, 128, 256, 512],
        'batch_size': 128,
        'learning_rate': 0.001,
        'optimizer': optim.Adam
    },
    {
        'name': "Configuration-13",
        'num_hidden_layers': 2,
        'hidden_layer_sizes': [128, 256],
        'batch_size': 256,
        'learning_rate': 0.001,
        'optimizer': optim.RMSprop
    },
    {
        'name': "Configuration-14",
        'num_hidden_layers': 1,
        'hidden_layer_sizes': [512],
        'batch_size': 256,
        'learning_rate': 0.001,
        'optimizer': optim.Adam
    },
    {
        'name': "Configuration-15",
        'num_hidden_layers': 4,
        'hidden_layer_sizes': [64, 128, 256, 512],
        'batch_size': 32,
        'learning_rate': 0.001,
        'optimizer': optim.RMSprop
    }
]


# Running experiments
FC_results = []

for config in configurations:
    name = config['name']
    num_hidden_layers = config['num_hidden_layers']
    hidden_layer_sizes = config['hidden_layer_sizes']
    batch_size = config['batch_size']
    learning_rate = config['learning_rate']
    optimizer_func = config['optimizer']

    # Initialize model, loss function, and optimizer
    model = FashionMLP(num_hidden_layers, hidden_layer_sizes)
    criterion = nn.CrossEntropyLoss()
    optimizer = optimizer_func(model.parameters(), lr=learning_rate)

    # Display configuration
    print(f"Configuration - {name}")
    print("Input data:")
    print(f"- Num Hidden Layers: {num_hidden_layers}")
    print(f"- Hidden Layer Sizes: {hidden_layer_sizes}")
    print(f"- Batch Size: {batch_size}")
    print(f"- Learning Rate: {learning_rate}")

    # Training
    num_epochs = 10
    epoch_losses = []
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        for i, data in enumerate(train_loader, 0):
            inputs, labels = data
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

            # Print epoch-wise batch loss
            if i % 100 == 99:
                print(f'Epoch [{epoch + 1}], Batch [{i + 1}/{len(train_loader)}], Loss: {running_loss / 100:.4f}')
                running_loss = 0.0

        epoch_losses.append(running_loss)

    # Evaluating
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for data in test_loader:
            images, labels = data
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = correct / total
    print(f"Accuracy for {name}: {accuracy * 100:.2f}%\n")

    FC_results.append([name, num_hidden_layers, hidden_layer_sizes, batch_size, learning_rate, accuracy])

    # Print dotted line break
    print("." * 50)
    print()

# Display FC_results
print(tabulate(FC_results, headers=["Configuration", "Num Hidden Layers", "Hidden Layer Sizes", "Batch Size", "Learning Rate", "Accuracy"],
               floatfmt=".2f"))
# Out:
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (0.9.0)
# Configuration - Configuration-1
# Input data:
# - Num Hidden Layers: 3
# - Hidden Layer Sizes: [32, 64, 128]
# - Batch Size: 64
# - Learning Rate: 0.001
# Epoch [1], Batch [100/938], Loss: 2.2035
# Epoch [1], Batch [200/938], Loss: 1.5984
# Epoch [1], Batch [300/938], Loss: 1.2569
# Epoch [1], Batch [400/938], Loss: 1.0815
# Epoch [1], Batch [500/938], Loss: 0.9633
# Epoch [1], Batch [600/938], Loss: 0.8694
# Epoch [1], Batch [700/938], Loss: 0.8051
# Epoch [1], Batch [800/938], Loss: 0.7442
# Epoch [1], Batch [900/938], Loss: 0.7179
# Epoch [2], Batch [100/938], Loss: 0.6849
# Epoch [2], Batch [200/938], Loss: 0.6778
# Epoch [2], Batch [300/938], Loss: 0.6354
# Epoch [2], Batch [400/938], Loss: 0.6444
# Epoch [2], Batch [500/938], Loss: 0.6512
# Epoch [2], Batch [600/938], Loss: 0.6123
# Epoch [2], Batch [700/938], Loss: 0.6203
# Epoch [2], Batch [800/938], Loss: 0.6024
# Epoch [2], Batch [900/938], Loss: 0.5857
# Epoch [3], Batch [100/938], Loss: 0.5701
# Epoch [3], Batch [200/938], Loss: 0.5539
# Epoch [3], Batch [300/938], Loss: 0.5303
# Epoch [3], Batch [400/938], Loss: 0.5269
# Epoch [3], Batch [500/938], Loss: 0.5113
# Epoch [3], Batch [600/938], Loss: 0.5126
# Epoch [3], Batch [700/938], Loss: 0.5165
# Epoch [3], Batch [800/938], Loss: 0.4772
# Epoch [3], Batch [900/938], Loss: 0.4935
# Epoch [4], Batch [100/938], Loss: 0.4729
# Epoch [4], Batch [200/938], Loss: 0.4488
# Epoch [4], Batch [300/938], Loss: 0.4497
# Epoch [4], Batch [400/938], Loss: 0.4597
# Epoch [4], Batch [500/938], Loss: 0.4245
# Epoch [4], Batch [600/938], Loss: 0.4295
# Epoch [4], Batch [700/938], Loss: 0.4157
# Epoch [4], Batch [800/938], Loss: 0.4298
# Epoch [4], Batch [900/938], Loss: 0.4124
# Epoch [5], Batch [100/938], Loss: 0.4170
# Epoch [5], Batch [200/938], Loss: 0.4056
# Epoch [5], Batch [300/938], Loss: 0.4098
# Epoch [5], Batch [400/938], Loss: 0.3910
# Epoch [5], Batch [500/938], Loss: 0.3825
# Epoch [5], Batch [600/938], Loss: 0.4065
# Epoch [5], Batch [700/938], Loss: 0.3851
# Epoch [5], Batch [800/938], Loss: 0.3863
# Epoch [5], Batch [900/938], Loss: 0.3879
# Epoch [6], Batch [100/938], Loss: 0.3495
# Epoch [6], Batch [200/938], Loss: 0.3924
# Epoch [6], Batch [300/938], Loss: 0.3572
# Epoch [6], Batch [400/938], Loss: 0.3802
# Epoch [6], Batch [500/938], Loss: 0.3794
# Epoch [6], Batch [600/938], Loss: 0.3666
# Epoch [6], Batch [700/938], Loss: 0.3748
# Epoch [6], Batch [800/938], Loss: 0.3929
# Epoch [6], Batch [900/938], Loss: 0.3804
# Epoch [7], Batch [100/938], Loss: 0.3545
# Epoch [7], Batch [200/938], Loss: 0.3741
# Epoch [7], Batch [300/938], Loss: 0.3524
# Epoch [7], Batch [400/938], Loss: 0.3643
# Epoch [7], Batch [500/938], Loss: 0.3499
# Epoch [7], Batch [600/938], Loss: 0.3810
# Epoch [7], Batch [700/938], Loss: 0.3605
# Epoch [7], Batch [800/938], Loss: 0.3421
# Epoch [7], Batch [900/938], Loss: 0.3350
# Epoch [8], Batch [100/938], Loss: 0.3321
# Epoch [8], Batch [200/938], Loss: 0.3417
# Epoch [8], Batch [300/938], Loss: 0.3629
# Epoch [8], Batch [400/938], Loss: 0.3381
# Epoch [8], Batch [500/938], Loss: 0.3551
# Epoch [8], Batch [600/938], Loss: 0.3392
# Epoch [8], Batch [700/938], Loss: 0.3514
# Epoch [8], Batch [800/938], Loss: 0.3662
# Epoch [8], Batch [900/938], Loss: 0.3383
# Epoch [9], Batch [100/938], Loss: 0.3396
# Epoch [9], Batch [200/938], Loss: 0.3211
# Epoch [9], Batch [300/938], Loss: 0.3249
# Epoch [9], Batch [400/938], Loss: 0.3353
# Epoch [9], Batch [500/938], Loss: 0.3395
# Epoch [9], Batch [600/938], Loss: 0.3318
# Epoch [9], Batch [700/938], Loss: 0.3540
# Epoch [9], Batch [800/938], Loss: 0.3334
# Epoch [9], Batch [900/938], Loss: 0.3420
# Epoch [10], Batch [100/938], Loss: 0.3484
# Epoch [10], Batch [200/938], Loss: 0.3205
# Epoch [10], Batch [300/938], Loss: 0.3215
# Epoch [10], Batch [400/938], Loss: 0.3257
# Epoch [10], Batch [500/938], Loss: 0.3240
# Epoch [10], Batch [600/938], Loss: 0.3342
# Epoch [10], Batch [700/938], Loss: 0.3282
# Epoch [10], Batch [800/938], Loss: 0.3188
# Epoch [10], Batch [900/938], Loss: 0.3310
# Accuracy for Configuration-1: 85.86%
#
# ..................................................
#
# Configuration - Configuration-2
# Input data:
# - Num Hidden Layers: 3
# - Hidden Layer Sizes: [64, 128, 256]
# - Batch Size: 512
# - Learning Rate: 0.001
# Epoch [1], Batch [100/938], Loss: 1.5954
# Epoch [1], Batch [200/938], Loss: 1.0414
# Epoch [1], Batch [300/938], Loss: 0.8373
# Epoch [1], Batch [400/938], Loss: 0.7267
# Epoch [1], Batch [500/938], Loss: 0.6814
# Epoch [1], Batch [600/938], Loss: 0.6520
# Epoch [1], Batch [700/938], Loss: 0.6315
# Epoch [1], Batch [800/938], Loss: 0.5900
# Epoch [1], Batch [900/938], Loss: 0.5931
# Epoch [2], Batch [100/938], Loss: 0.5529
# Epoch [2], Batch [200/938], Loss: 0.5116
# Epoch [2], Batch [300/938], Loss: 0.4961
# Epoch [2], Batch [400/938], Loss: 0.4981
# Epoch [2], Batch [500/938], Loss: 0.4849
# Epoch [2], Batch [600/938], Loss: 0.4878
# Epoch [2], Batch [700/938], Loss: 0.4781
# Epoch [2], Batch [800/938], Loss: 0.4725
# Epoch [2], Batch [900/938], Loss: 0.4555
# Epoch [3], Batch [100/938], Loss: 0.4513
# Epoch [3], Batch [200/938], Loss: 0.4313
# Epoch [3], Batch [300/938], Loss: 0.4233
# Epoch [3], Batch [400/938], Loss: 0.4118
# Epoch [3], Batch [500/938], Loss: 0.4208
# Epoch [3], Batch [600/938], Loss: 0.4145
# Epoch [3], Batch [700/938], Loss: 0.4057
# Epoch [3], Batch [800/938], Loss: 0.4214
# Epoch [3], Batch [900/938], Loss: 0.4275
# Epoch [4], Batch [100/938], Loss: 0.3873
# Epoch [4], Batch [200/938], Loss: 0.4102
# Epoch [4], Batch [300/938], Loss: 0.3914
# Epoch [4], Batch [400/938], Loss: 0.3799
# Epoch [4], Batch [500/938], Loss: 0.3850
# Epoch [4], Batch [600/938], Loss: 0.3899
# Epoch [4], Batch [700/938], Loss: 0.3764
# Epoch [4], Batch [800/938], Loss: 0.3647
# Epoch [4], Batch [900/938], Loss: 0.3851
# Epoch [5], Batch [100/938], Loss: 0.3693
# Epoch [5], Batch [200/938], Loss: 0.3512
# Epoch [5], Batch [300/938], Loss: 0.3842
# Epoch [5], Batch [400/938], Loss: 0.3665
# Epoch [5], Batch [500/938], Loss: 0.3730
# Epoch [5], Batch [600/938], Loss: 0.3512
# Epoch [5], Batch [700/938], Loss: 0.3623
# Epoch [5], Batch [800/938], Loss: 0.3427
# Epoch [5], Batch [900/938], Loss: 0.3439
# Epoch [6], Batch [100/938], Loss: 0.3516
# Epoch [6], Batch [200/938], Loss: 0.3391
# Epoch [6], Batch [300/938], Loss: 0.3400
# Epoch [6], Batch [400/938], Loss: 0.3600
# Epoch [6], Batch [500/938], Loss: 0.3508
# Epoch [6], Batch [600/938], Loss: 0.3426
# Epoch [6], Batch [700/938], Loss: 0.3462
# Epoch [6], Batch [800/938], Loss: 0.3377
# Epoch [6], Batch [900/938], Loss: 0.3272
# Epoch [7], Batch [100/938], Loss: 0.3437
# Epoch [7], Batch [200/938], Loss: 0.3392
# Epoch [7], Batch [300/938], Loss: 0.3249
# Epoch [7], Batch [400/938], Loss: 0.3261
# Epoch [7], Batch [500/938], Loss: 0.3337
# Epoch [7], Batch [600/938], Loss: 0.3220
# Epoch [7], Batch [700/938], Loss: 0.3212
# Epoch [7], Batch [800/938], Loss: 0.3234
# Epoch [7], Batch [900/938], Loss: 0.3149
# Epoch [8], Batch [100/938], Loss: 0.3122
# Epoch [8], Batch [200/938], Loss: 0.3175
# Epoch [8], Batch [300/938], Loss: 0.3048
# Epoch [8], Batch [400/938], Loss: 0.3278
# Epoch [8], Batch [500/938], Loss: 0.3341
# Epoch [8], Batch [600/938], Loss: 0.3175
# Epoch [8], Batch [700/938], Loss: 0.3128
# Epoch [8], Batch [800/938], Loss: 0.3159
# Epoch [8], Batch [900/938], Loss: 0.3138
# Epoch [9], Batch [100/938], Loss: 0.3075
# Epoch [9], Batch [200/938], Loss: 0.2977
# Epoch [9], Batch [300/938], Loss: 0.2970
# Epoch [9], Batch [400/938], Loss: 0.2852
# Epoch [9], Batch [500/938], Loss: 0.3001
# Epoch [9], Batch [600/938], Loss: 0.3100
# Epoch [9], Batch [700/938], Loss: 0.3243
# Epoch [9], Batch [800/938], Loss: 0.3164
# Epoch [9], Batch [900/938], Loss: 0.3002
# Epoch [10], Batch [100/938], Loss: 0.2873
# Epoch [10], Batch [200/938], Loss: 0.2979
# Epoch [10], Batch [300/938], Loss: 0.2970
# Epoch [10], Batch [400/938], Loss: 0.3091
# Epoch [10], Batch [500/938], Loss: 0.2898
# Epoch [10], Batch [600/938], Loss: 0.3063
# Epoch [10], Batch [700/938], Loss: 0.2923
# Epoch [10], Batch [800/938], Loss: 0.2776
# Epoch [10], Batch [900/938], Loss: 0.3016
# Accuracy for Configuration-2: 83.65%
#
# ..................................................
#
# Configuration - Configuration-3
# Input data:
# - Num Hidden Layers: 3
# - Hidden Layer Sizes: [128, 256, 512]
# - Batch Size: 64
# - Learning Rate: 0.001
# Epoch [1], Batch [100/938], Loss: 1.7136
# Epoch [1], Batch [200/938], Loss: 0.9039
# Epoch [1], Batch [300/938], Loss: 0.7334
# Epoch [1], Batch [400/938], Loss: 0.6828
# Epoch [1], Batch [500/938], Loss: 0.6215
# Epoch [1], Batch [600/938], Loss: 0.5889
# Epoch [1], Batch [700/938], Loss: 0.5456
# Epoch [1], Batch [800/938], Loss: 0.5371
# Epoch [1], Batch [900/938], Loss: 0.5309
# Epoch [2], Batch [100/938], Loss: 0.4609
# Epoch [2], Batch [200/938], Loss: 0.4503
# Epoch [2], Batch [300/938], Loss: 0.4705
# Epoch [2], Batch [400/938], Loss: 0.4358
# Epoch [2], Batch [500/938], Loss: 0.4314
# Epoch [2], Batch [600/938], Loss: 0.4249
# Epoch [2], Batch [700/938], Loss: 0.4379
# Epoch [2], Batch [800/938], Loss: 0.4379
# Epoch [2], Batch [900/938], Loss: 0.4225
# Epoch [3], Batch [100/938], Loss: 0.3734
# Epoch [3], Batch [200/938], Loss: 0.3836
# Epoch [3], Batch [300/938], Loss: 0.3868
# Epoch [3], Batch [400/938], Loss: 0.3868
# Epoch [3], Batch [500/938], Loss: 0.3824
# Epoch [3], Batch [600/938], Loss: 0.4166
# Epoch [3], Batch [700/938], Loss: 0.3751
# Epoch [3], Batch [800/938], Loss: 0.3810
# Epoch [3], Batch [900/938], Loss: 0.3619
# Epoch [4], Batch [100/938], Loss: 0.3493
# Epoch [4], Batch [200/938], Loss: 0.3655
# Epoch [4], Batch [300/938], Loss: 0.3493
# Epoch [4], Batch [400/938], Loss: 0.3589
# Epoch [4], Batch [500/938], Loss: 0.3476
# Epoch [4], Batch [600/938], Loss: 0.3389
# Epoch [4], Batch [700/938], Loss: 0.3526
# Epoch [4], Batch [800/938], Loss: 0.3345
# Epoch [4], Batch [900/938], Loss: 0.3455
# Epoch [5], Batch [100/938], Loss: 0.3153
# Epoch [5], Batch [200/938], Loss: 0.3271
# Epoch [5], Batch [300/938], Loss: 0.3345
# Epoch [5], Batch [400/938], Loss: 0.3424
# Epoch [5], Batch [500/938], Loss: 0.3198
# Epoch [5], Batch [600/938], Loss: 0.3271
# Epoch [5], Batch [700/938], Loss: 0.3254
# Epoch [5], Batch [800/938], Loss: 0.3251
# Epoch [5], Batch [900/938], Loss: 0.3075
# Epoch [6], Batch [100/938], Loss: 0.3082
# Epoch [6], Batch [200/938], Loss: 0.3008
# Epoch [6], Batch [300/938], Loss: 0.3206
# Epoch [6], Batch [400/938], Loss: 0.3239
# Epoch [6], Batch [500/938], Loss: 0.3188
# Epoch [6], Batch [600/938], Loss: 0.3078
# Epoch [6], Batch [700/938], Loss: 0.2988
# Epoch [6], Batch [800/938], Loss: 0.2932
# Epoch [6], Batch [900/938], Loss: 0.3194
# Epoch [7], Batch [100/938], Loss: 0.2982
# Epoch [7], Batch [200/938], Loss: 0.2807
# Epoch [7], Batch [300/938], Loss: 0.3039
# Epoch [7], Batch [400/938], Loss: 0.2974
# Epoch [7], Batch [500/938], Loss: 0.2897
# Epoch [7], Batch [600/938], Loss: 0.3054
# Epoch [7], Batch [700/938], Loss: 0.2874
# Epoch [7], Batch [800/938], Loss: 0.2817
# Epoch [7], Batch [900/938], Loss: 0.3053
# Epoch [8], Batch [100/938], Loss: 0.2750
# Epoch [8], Batch [200/938], Loss: 0.2671
# Epoch [8], Batch [300/938], Loss: 0.2783
# Epoch [8], Batch [400/938], Loss: 0.2720
# Epoch [8], Batch [500/938], Loss: 0.2925
# Epoch [8], Batch [600/938], Loss: 0.3023
# Epoch [8], Batch [700/938], Loss: 0.2764
# Epoch [8], Batch [800/938], Loss: 0.2935
# Epoch [8], Batch [900/938], Loss: 0.2764
# Epoch [9], Batch [100/938], Loss: 0.2664
# Epoch [9], Batch [200/938], Loss: 0.2758
# Epoch [9], Batch [300/938], Loss: 0.2727
# Epoch [9], Batch [400/938], Loss: 0.2831
# Epoch [9], Batch [500/938], Loss: 0.2636
# Epoch [9], Batch [600/938], Loss: 0.2818
# Epoch [9], Batch [700/938], Loss: 0.2660
# Epoch [9], Batch [800/938], Loss: 0.2637
# Epoch [9], Batch [900/938], Loss: 0.2809
# Epoch [10], Batch [100/938], Loss: 0.2500
# Epoch [10], Batch [200/938], Loss: 0.2673
# Epoch [10], Batch [300/938], Loss: 0.2695
# Epoch [10], Batch [400/938], Loss: 0.2615
# Epoch [10], Batch [500/938], Loss: 0.2483
# Epoch [10], Batch [600/938], Loss: 0.2635
# Epoch [10], Batch [700/938], Loss: 0.2516
# Epoch [10], Batch [800/938], Loss: 0.2630
# Epoch [10], Batch [900/938], Loss: 0.2660
# Accuracy for Configuration-3: 87.50%
#
# ..................................................
#
# Configuration - Configuration-4
# Input data:
# - Num Hidden Layers: 2
# - Hidden Layer Sizes: [64, 128]
# - Batch Size: 64
# - Learning Rate: 0.001
# Epoch [1], Batch [100/938], Loss: 1.8498
# Epoch [1], Batch [200/938], Loss: 1.1225
# Epoch [1], Batch [300/938], Loss: 0.8254
# Epoch [1], Batch [400/938], Loss: 0.7020
# Epoch [1], Batch [500/938], Loss: 0.6065
# Epoch [1], Batch [600/938], Loss: 0.5631
# Epoch [1], Batch [700/938], Loss: 0.5315
# Epoch [1], Batch [800/938], Loss: 0.5214
# Epoch [1], Batch [900/938], Loss: 0.4591
# Epoch [2], Batch [100/938], Loss: 0.4554
# Epoch [2], Batch [200/938], Loss: 0.4365
# Epoch [2], Batch [300/938], Loss: 0.4412
# Epoch [2], Batch [400/938], Loss: 0.4386
# Epoch [2], Batch [500/938], Loss: 0.4193
# Epoch [2], Batch [600/938], Loss: 0.4142
# Epoch [2], Batch [700/938], Loss: 0.4288
# Epoch [2], Batch [800/938], Loss: 0.4034
# Epoch [2], Batch [900/938], Loss: 0.3901
# Epoch [3], Batch [100/938], Loss: 0.3798
# Epoch [3], Batch [200/938], Loss: 0.3757
# Epoch [3], Batch [300/938], Loss: 0.3917
# Epoch [3], Batch [400/938], Loss: 0.3847
# Epoch [3], Batch [500/938], Loss: 0.3513
# Epoch [3], Batch [600/938], Loss: 0.3677
# Epoch [3], Batch [700/938], Loss: 0.3605
# Epoch [3], Batch [800/938], Loss: 0.3629
# Epoch [3], Batch [900/938], Loss: 0.3733
# Epoch [4], Batch [100/938], Loss: 0.3320
# Epoch [4], Batch [200/938], Loss: 0.3453
# Epoch [4], Batch [300/938], Loss: 0.3504
# Epoch [4], Batch [400/938], Loss: 0.3607
# Epoch [4], Batch [500/938], Loss: 0.3423
# Epoch [4], Batch [600/938], Loss: 0.3512
# Epoch [4], Batch [700/938], Loss: 0.3468
# Epoch [4], Batch [800/938], Loss: 0.3344
# Epoch [4], Batch [900/938], Loss: 0.3261
# Epoch [5], Batch [100/938], Loss: 0.3269
# Epoch [5], Batch [200/938], Loss: 0.3248
# Epoch [5], Batch [300/938], Loss: 0.3212
# Epoch [5], Batch [400/938], Loss: 0.3228
# Epoch [5], Batch [500/938], Loss: 0.3325
# Epoch [5], Batch [600/938], Loss: 0.2944
# Epoch [5], Batch [700/938], Loss: 0.3292
# Epoch [5], Batch [800/938], Loss: 0.3286
# Epoch [5], Batch [900/938], Loss: 0.3342
# Epoch [6], Batch [100/938], Loss: 0.3023
# Epoch [6], Batch [200/938], Loss: 0.2910
# Epoch [6], Batch [300/938], Loss: 0.3242
# Epoch [6], Batch [400/938], Loss: 0.3092
# Epoch [6], Batch [500/938], Loss: 0.3043
# Epoch [6], Batch [600/938], Loss: 0.3083
# Epoch [6], Batch [700/938], Loss: 0.3101
# Epoch [6], Batch [800/938], Loss: 0.3220
# Epoch [6], Batch [900/938], Loss: 0.3092
# Epoch [7], Batch [100/938], Loss: 0.2885
# Epoch [7], Batch [200/938], Loss: 0.2969
# Epoch [7], Batch [300/938], Loss: 0.2878
# Epoch [7], Batch [400/938], Loss: 0.2900
# Epoch [7], Batch [500/938], Loss: 0.3077
# Epoch [7], Batch [600/938], Loss: 0.3129
# Epoch [7], Batch [700/938], Loss: 0.3077
# Epoch [7], Batch [800/938], Loss: 0.3010
# Epoch [7], Batch [900/938], Loss: 0.2996
# Epoch [8], Batch [100/938], Loss: 0.2812
# Epoch [8], Batch [200/938], Loss: 0.2706
# Epoch [8], Batch [300/938], Loss: 0.2892
# Epoch [8], Batch [400/938], Loss: 0.2898
# Epoch [8], Batch [500/938], Loss: 0.2908
# Epoch [8], Batch [600/938], Loss: 0.2769
# Epoch [8], Batch [700/938], Loss: 0.2913
# Epoch [8], Batch [800/938], Loss: 0.2947
# Epoch [8], Batch [900/938], Loss: 0.2842
# Epoch [9], Batch [100/938], Loss: 0.2751
# Epoch [9], Batch [200/938], Loss: 0.2677
# Epoch [9], Batch [300/938], Loss: 0.2809
# Epoch [9], Batch [400/938], Loss: 0.2783
# Epoch [9], Batch [500/938], Loss: 0.2777
# Epoch [9], Batch [600/938], Loss: 0.2674
# Epoch [9], Batch [700/938], Loss: 0.2857
# Epoch [9], Batch [800/938], Loss: 0.2775
# Epoch [9], Batch [900/938], Loss: 0.2866
# Epoch [10], Batch [100/938], Loss: 0.2751
# Epoch [10], Batch [200/938], Loss: 0.2680
# Epoch [10], Batch [300/938], Loss: 0.2713
# Epoch [10], Batch [400/938], Loss: 0.2793
# Epoch [10], Batch [500/938], Loss: 0.2775
# Epoch [10], Batch [600/938], Loss: 0.2744
# Epoch [10], Batch [700/938], Loss: 0.2713
# Epoch [10], Batch [800/938], Loss: 0.2586
# Epoch [10], Batch [900/938], Loss: 0.2677
# Accuracy for Configuration-4: 87.63%
#
# ..................................................
#
# Configuration - Configuration-5
# Input data:
# - Num Hidden Layers: 2
# - Hidden Layer Sizes: [32, 64]
# - Batch Size: 64
# - Learning Rate: 0.001
# Epoch [1], Batch [100/938], Loss: 2.0591
# Epoch [1], Batch [200/938], Loss: 1.4761
# Epoch [1], Batch [300/938], Loss: 1.1512
# Epoch [1], Batch [400/938], Loss: 0.9382
# Epoch [1], Batch [500/938], Loss: 0.7957
# Epoch [1], Batch [600/938], Loss: 0.7042
# Epoch [1], Batch [700/938], Loss: 0.6493
# Epoch [1], Batch [800/938], Loss: 0.6297
# Epoch [1], Batch [900/938], Loss: 0.5738
# Epoch [2], Batch [100/938], Loss: 0.5291
# Epoch [2], Batch [200/938], Loss: 0.5240
# Epoch [2], Batch [300/938], Loss: 0.4941
# Epoch [2], Batch [400/938], Loss: 0.5040
# Epoch [2], Batch [500/938], Loss: 0.4804
# Epoch [2], Batch [600/938], Loss: 0.4764
# Epoch [2], Batch [700/938], Loss: 0.4658
# Epoch [2], Batch [800/938], Loss: 0.4469
# Epoch [2], Batch [900/938], Loss: 0.4537
# Epoch [3], Batch [100/938], Loss: 0.4264
# Epoch [3], Batch [200/938], Loss: 0.4306
# Epoch [3], Batch [300/938], Loss: 0.4335
# Epoch [3], Batch [400/938], Loss: 0.4107
# Epoch [3], Batch [500/938], Loss: 0.4318
# Epoch [3], Batch [600/938], Loss: 0.4205
# Epoch [3], Batch [700/938], Loss: 0.4060
# Epoch [3], Batch [800/938], Loss: 0.4199
# Epoch [3], Batch [900/938], Loss: 0.3933
# Epoch [4], Batch [100/938], Loss: 0.3856
# Epoch [4], Batch [200/938], Loss: 0.3849
# Epoch [4], Batch [300/938], Loss: 0.3924
# Epoch [4], Batch [400/938], Loss: 0.3725
# Epoch [4], Batch [500/938], Loss: 0.3951
# Epoch [4], Batch [600/938], Loss: 0.3955
# Epoch [4], Batch [700/938], Loss: 0.3852
# Epoch [4], Batch [800/938], Loss: 0.3951
# Epoch [4], Batch [900/938], Loss: 0.4025
# Epoch [5], Batch [100/938], Loss: 0.3677
# Epoch [5], Batch [200/938], Loss: 0.3654
# Epoch [5], Batch [300/938], Loss: 0.3661
# Epoch [5], Batch [400/938], Loss: 0.3578
# Epoch [5], Batch [500/938], Loss: 0.3597
# Epoch [5], Batch [600/938], Loss: 0.3735
# Epoch [5], Batch [700/938], Loss: 0.3787
# Epoch [5], Batch [800/938], Loss: 0.3642
# Epoch [5], Batch [900/938], Loss: 0.3728
# Epoch [6], Batch [100/938], Loss: 0.3618
# Epoch [6], Batch [200/938], Loss: 0.3290
# Epoch [6], Batch [300/938], Loss: 0.3557
# Epoch [6], Batch [400/938], Loss: 0.3457
# Epoch [6], Batch [500/938], Loss: 0.3587
# Epoch [6], Batch [600/938], Loss: 0.3571
# Epoch [6], Batch [700/938], Loss: 0.3611
# Epoch [6], Batch [800/938], Loss: 0.3574
# Epoch [6], Batch [900/938], Loss: 0.3486
# Epoch [7], Batch [100/938], Loss: 0.3572
# Epoch [7], Batch [200/938], Loss: 0.3318
# Epoch [7], Batch [300/938], Loss: 0.3310
# Epoch [7], Batch [400/938], Loss: 0.3468
# Epoch [7], Batch [500/938], Loss: 0.3255
# Epoch [7], Batch [600/938], Loss: 0.3521
# Epoch [7], Batch [700/938], Loss: 0.3416
# Epoch [7], Batch [800/938], Loss: 0.3481
# Epoch [7], Batch [900/938], Loss: 0.3377
# Epoch [8], Batch [100/938], Loss: 0.3423
# Epoch [8], Batch [200/938], Loss: 0.3310
# Epoch [8], Batch [300/938], Loss: 0.3259
# Epoch [8], Batch [400/938], Loss: 0.3227
# Epoch [8], Batch [500/938], Loss: 0.3250
# Epoch [8], Batch [600/938], Loss: 0.3282
# Epoch [8], Batch [700/938], Loss: 0.3123
# Epoch [8], Batch [800/938], Loss: 0.3464
# Epoch [8], Batch [900/938], Loss: 0.3325
# Epoch [9], Batch [100/938], Loss: 0.3199
# Epoch [9], Batch [200/938], Loss: 0.3234
# Epoch [9], Batch [300/938], Loss: 0.3382
# Epoch [9], Batch [400/938], Loss: 0.3150
# Epoch [9], Batch [500/938], Loss: 0.3320
# Epoch [9], Batch [600/938], Loss: 0.3168
# Epoch [9], Batch [700/938], Loss: 0.3151
# Epoch [9], Batch [800/938], Loss: 0.3237
# Epoch [9], Batch [900/938], Loss: 0.3223
# Epoch [10], Batch [100/938], Loss: 0.3185
# Epoch [10], Batch [200/938], Loss: 0.3254
# Epoch [10], Batch [300/938], Loss: 0.2984
# Epoch [10], Batch [400/938], Loss: 0.3133
# Epoch [10], Batch [500/938], Loss: 0.3091
# Epoch [10], Batch [600/938], Loss: 0.3098
# Epoch [10], Batch [700/938], Loss: 0.3288
# Epoch [10], Batch [800/938], Loss: 0.3088
# Epoch [10], Batch [900/938], Loss: 0.3205
# Accuracy for Configuration-5: 86.13%
#
# ..................................................
#
# Configuration - Configuration-6
# Input data:
# - Num Hidden Layers: 2
# - Hidden Layer Sizes: [128, 256]
# - Batch Size: 64
# - Learning Rate: 0.001
# Epoch [1], Batch [100/938], Loss: 1.5670
# Epoch [1], Batch [200/938], Loss: 0.7956
# Epoch [1], Batch [300/938], Loss: 0.6306
# Epoch [1], Batch [400/938], Loss: 0.5568
# Epoch [1], Batch [500/938], Loss: 0.5099
# Epoch [1], Batch [600/938], Loss: 0.4876
# Epoch [1], Batch [700/938], Loss: 0.4785
# Epoch [1], Batch [800/938], Loss: 0.4447
# Epoch [1], Batch [900/938], Loss: 0.4366
# Epoch [2], Batch [100/938], Loss: 0.4179
# Epoch [2], Batch [200/938], Loss: 0.3982
# Epoch [2], Batch [300/938], Loss: 0.4187
# Epoch [2], Batch [400/938], Loss: 0.3986
# Epoch [2], Batch [500/938], Loss: 0.4009
# Epoch [2], Batch [600/938], Loss: 0.3764
# Epoch [2], Batch [700/938], Loss: 0.3915
# Epoch [2], Batch [800/938], Loss: 0.3836
# Epoch [2], Batch [900/938], Loss: 0.3871
# Epoch [3], Batch [100/938], Loss: 0.3715
# Epoch [3], Batch [200/938], Loss: 0.3643
# Epoch [3], Batch [300/938], Loss: 0.3663
# Epoch [3], Batch [400/938], Loss: 0.3422
# Epoch [3], Batch [500/938], Loss: 0.3605
# Epoch [3], Batch [600/938], Loss: 0.3454
# Epoch [3], Batch [700/938], Loss: 0.3473
# Epoch [3], Batch [800/938], Loss: 0.3296
# Epoch [3], Batch [900/938], Loss: 0.3556
# Epoch [4], Batch [100/938], Loss: 0.3272
# Epoch [4], Batch [200/938], Loss: 0.3252
# Epoch [4], Batch [300/938], Loss: 0.3379
# Epoch [4], Batch [400/938], Loss: 0.3358
# Epoch [4], Batch [500/938], Loss: 0.3343
# Epoch [4], Batch [600/938], Loss: 0.3255
# Epoch [4], Batch [700/938], Loss: 0.3104
# Epoch [4], Batch [800/938], Loss: 0.3126
# Epoch [4], Batch [900/938], Loss: 0.3263
# Epoch [5], Batch [100/938], Loss: 0.2939
# Epoch [5], Batch [200/938], Loss: 0.3027
# Epoch [5], Batch [300/938], Loss: 0.3224
# Epoch [5], Batch [400/938], Loss: 0.2903
# Epoch [5], Batch [500/938], Loss: 0.3106
# Epoch [5], Batch [600/938], Loss: 0.3091
# Epoch [5], Batch [700/938], Loss: 0.3058
# Epoch [5], Batch [800/938], Loss: 0.3187
# Epoch [5], Batch [900/938], Loss: 0.3021
# Epoch [6], Batch [100/938], Loss: 0.2769
# Epoch [6], Batch [200/938], Loss: 0.2964
# Epoch [6], Batch [300/938], Loss: 0.3051
# Epoch [6], Batch [400/938], Loss: 0.2913
# Epoch [6], Batch [500/938], Loss: 0.2857
# Epoch [6], Batch [600/938], Loss: 0.2966
# Epoch [6], Batch [700/938], Loss: 0.2967
# Epoch [6], Batch [800/938], Loss: 0.2828
# Epoch [6], Batch [900/938], Loss: 0.2881
# Epoch [7], Batch [100/938], Loss: 0.2650
# Epoch [7], Batch [200/938], Loss: 0.2609
# Epoch [7], Batch [300/938], Loss: 0.2750
# Epoch [7], Batch [400/938], Loss: 0.2862
# Epoch [7], Batch [500/938], Loss: 0.2685
# Epoch [7], Batch [600/938], Loss: 0.2937
# Epoch [7], Batch [700/938], Loss: 0.2889
# Epoch [7], Batch [800/938], Loss: 0.2684
# Epoch [7], Batch [900/938], Loss: 0.2842
# Epoch [8], Batch [100/938], Loss: 0.2709
# Epoch [8], Batch [200/938], Loss: 0.2635
# Epoch [8], Batch [300/938], Loss: 0.2645
# Epoch [8], Batch [400/938], Loss: 0.2392
# Epoch [8], Batch [500/938], Loss: 0.2708
# Epoch [8], Batch [600/938], Loss: 0.2796
# Epoch [8], Batch [700/938], Loss: 0.2667
# Epoch [8], Batch [800/938], Loss: 0.2745
# Epoch [8], Batch [900/938], Loss: 0.2641
# Epoch [9], Batch [100/938], Loss: 0.2582
# Epoch [9], Batch [200/938], Loss: 0.2494
# Epoch [9], Batch [300/938], Loss: 0.2512
# Epoch [9], Batch [400/938], Loss: 0.2477
# Epoch [9], Batch [500/938], Loss: 0.2681
# Epoch [9], Batch [600/938], Loss: 0.2526
# Epoch [9], Batch [700/938], Loss: 0.2480
# Epoch [9], Batch [800/938], Loss: 0.2541
# Epoch [9], Batch [900/938], Loss: 0.2717
# Epoch [10], Batch [100/938], Loss: 0.2441
# Epoch [10], Batch [200/938], Loss: 0.2472
# Epoch [10], Batch [300/938], Loss: 0.2428
# Epoch [10], Batch [400/938], Loss: 0.2482
# Epoch [10], Batch [500/938], Loss: 0.2555
# Epoch [10], Batch [600/938], Loss: 0.2512
# Epoch [10], Batch [700/938], Loss: 0.2530
# Epoch [10], Batch [800/938], Loss: 0.2471
# Epoch [10], Batch [900/938], Loss: 0.2259
# Accuracy for Configuration-6: 87.84%
#
# ..................................................
#
# Configuration - Configuration-7
# Input data:
# - Num Hidden Layers: 2
# - Hidden Layer Sizes: [256, 512]
# - Batch Size: 64
# - Learning Rate: 0.001
# Epoch [1], Batch [100/938], Loss: 1.0660
# Epoch [1], Batch [200/938], Loss: 0.5908
# Epoch [1], Batch [300/938], Loss: 0.5509
# Epoch [1], Batch [400/938], Loss: 0.4987
# Epoch [1], Batch [500/938], Loss: 0.4684
# Epoch [1], Batch [600/938], Loss: 0.4511
# Epoch [1], Batch [700/938], Loss: 0.4617
# Epoch [1], Batch [800/938], Loss: 0.4457
# Epoch [1], Batch [900/938], Loss: 0.4258
# Epoch [2], Batch [100/938], Loss: 0.3877
# Epoch [2], Batch [200/938], Loss: 0.4152
# Epoch [2], Batch [300/938], Loss: 0.3790
# Epoch [2], Batch [400/938], Loss: 0.3818
# Epoch [2], Batch [500/938], Loss: 0.3764
# Epoch [2], Batch [600/938], Loss: 0.3873
# Epoch [2], Batch [700/938], Loss: 0.3776
# Epoch [2], Batch [800/938], Loss: 0.3868
# Epoch [2], Batch [900/938], Loss: 0.3787
# Epoch [3], Batch [100/938], Loss: 0.3362
# Epoch [3], Batch [200/938], Loss: 0.3492
# Epoch [3], Batch [300/938], Loss: 0.3440
# Epoch [3], Batch [400/938], Loss: 0.3504
# Epoch [3], Batch [500/938], Loss: 0.3528
# Epoch [3], Batch [600/938], Loss: 0.3416
# Epoch [3], Batch [700/938], Loss: 0.3474
# Epoch [3], Batch [800/938], Loss: 0.3301
# Epoch [3], Batch [900/938], Loss: 0.3452
# Epoch [4], Batch [100/938], Loss: 0.3334
# Epoch [4], Batch [200/938], Loss: 0.3199
# Epoch [4], Batch [300/938], Loss: 0.3056
# Epoch [4], Batch [400/938], Loss: 0.3243
# Epoch [4], Batch [500/938], Loss: 0.3149
# Epoch [4], Batch [600/938], Loss: 0.3142
# Epoch [4], Batch [700/938], Loss: 0.3083
# Epoch [4], Batch [800/938], Loss: 0.3247
# Epoch [4], Batch [900/938], Loss: 0.3076
# Epoch [5], Batch [100/938], Loss: 0.2967
# Epoch [5], Batch [200/938], Loss: 0.3034
# Epoch [5], Batch [300/938], Loss: 0.3156
# Epoch [5], Batch [400/938], Loss: 0.2891
# Epoch [5], Batch [500/938], Loss: 0.2967
# Epoch [5], Batch [600/938], Loss: 0.2866
# Epoch [5], Batch [700/938], Loss: 0.2822
# Epoch [5], Batch [800/938], Loss: 0.2961
# Epoch [5], Batch [900/938], Loss: 0.2955
# Epoch [6], Batch [100/938], Loss: 0.2829
# Epoch [6], Batch [200/938], Loss: 0.2670
# Epoch [6], Batch [300/938], Loss: 0.2877
# Epoch [6], Batch [400/938], Loss: 0.2735
# Epoch [6], Batch [500/938], Loss: 0.2680
# Epoch [6], Batch [600/938], Loss: 0.2777
# Epoch [6], Batch [700/938], Loss: 0.2852
# Epoch [6], Batch [800/938], Loss: 0.2839
# Epoch [6], Batch [900/938], Loss: 0.2807
# Epoch [7], Batch [100/938], Loss: 0.2568
# Epoch [7], Batch [200/938], Loss: 0.2740
# Epoch [7], Batch [300/938], Loss: 0.2630
# Epoch [7], Batch [400/938], Loss: 0.2841
# Epoch [7], Batch [500/938], Loss: 0.2532
# Epoch [7], Batch [600/938], Loss: 0.2620
# Epoch [7], Batch [700/938], Loss: 0.2579
# Epoch [7], Batch [800/938], Loss: 0.2614
# Epoch [7], Batch [900/938], Loss: 0.2622
# Epoch [8], Batch [100/938], Loss: 0.2426
# Epoch [8], Batch [200/938], Loss: 0.2534
# Epoch [8], Batch [300/938], Loss: 0.2634
# Epoch [8], Batch [400/938], Loss: 0.2486
# Epoch [8], Batch [500/938], Loss: 0.2591
# Epoch [8], Batch [600/938], Loss: 0.2512
# Epoch [8], Batch [700/938], Loss: 0.2475
# Epoch [8], Batch [800/938], Loss: 0.2437
# Epoch [8], Batch [900/938], Loss: 0.2481
# Epoch [9], Batch [100/938], Loss: 0.2385
# Epoch [9], Batch [200/938], Loss: 0.2247
# Epoch [9], Batch [300/938], Loss: 0.2454
# Epoch [9], Batch [400/938], Loss: 0.2230
# Epoch [9], Batch [500/938], Loss: 0.2406
# Epoch [9], Batch [600/938], Loss: 0.2375
# Epoch [9], Batch [700/938], Loss: 0.2349
# Epoch [9], Batch [800/938], Loss: 0.2396
# Epoch [9], Batch [900/938], Loss: 0.2390
# Epoch [10], Batch [100/938], Loss: 0.2084
# Epoch [10], Batch [200/938], Loss: 0.2209
# Epoch [10], Batch [300/938], Loss: 0.2257
# Epoch [10], Batch [400/938], Loss: 0.2237
# Epoch [10], Batch [500/938], Loss: 0.2365
# Epoch [10], Batch [600/938], Loss: 0.2427
# Epoch [10], Batch [700/938], Loss: 0.2122
# Epoch [10], Batch [800/938], Loss: 0.2333
# Epoch [10], Batch [900/938], Loss: 0.2318
# Accuracy for Configuration-7: 88.33%
#
# ..................................................
#
# Configuration - Configuration-8
# Input data:
# - Num Hidden Layers: 1
# - Hidden Layer Sizes: [64]
# - Batch Size: 64
# - Learning Rate: 0.001
# Epoch [1], Batch [100/938], Loss: 1.3881
# Epoch [1], Batch [200/938], Loss: 0.8128
# Epoch [1], Batch [300/938], Loss: 0.6485
# Epoch [1], Batch [400/938], Loss: 0.5760
# Epoch [1], Batch [500/938], Loss: 0.5448
# Epoch [1], Batch [600/938], Loss: 0.5123
# Epoch [1], Batch [700/938], Loss: 0.5056
# Epoch [1], Batch [800/938], Loss: 0.4690
# Epoch [1], Batch [900/938], Loss: 0.4593
# Epoch [2], Batch [100/938], Loss: 0.4534
# Epoch [2], Batch [200/938], Loss: 0.4156
# Epoch [2], Batch [300/938], Loss: 0.4242
# Epoch [2], Batch [400/938], Loss: 0.4317
# Epoch [2], Batch [500/938], Loss: 0.3998
# Epoch [2], Batch [600/938], Loss: 0.4143
# Epoch [2], Batch [700/938], Loss: 0.4115
# Epoch [2], Batch [800/938], Loss: 0.4026
# Epoch [2], Batch [900/938], Loss: 0.4115
# Epoch [3], Batch [100/938], Loss: 0.3876
# Epoch [3], Batch [200/938], Loss: 0.3948
# Epoch [3], Batch [300/938], Loss: 0.4036
# Epoch [3], Batch [400/938], Loss: 0.3638
# Epoch [3], Batch [500/938], Loss: 0.3639
# Epoch [3], Batch [600/938], Loss: 0.3776
# Epoch [3], Batch [700/938], Loss: 0.3800
# Epoch [3], Batch [800/938], Loss: 0.3764
# Epoch [3], Batch [900/938], Loss: 0.3622
# Epoch [4], Batch [100/938], Loss: 0.3552
# Epoch [4], Batch [200/938], Loss: 0.3579
# Epoch [4], Batch [300/938], Loss: 0.3456
# Epoch [4], Batch [400/938], Loss: 0.3592
# Epoch [4], Batch [500/938], Loss: 0.3576
# Epoch [4], Batch [600/938], Loss: 0.3541
# Epoch [4], Batch [700/938], Loss: 0.3470
# Epoch [4], Batch [800/938], Loss: 0.3566
# Epoch [4], Batch [900/938], Loss: 0.3492
# Epoch [5], Batch [100/938], Loss: 0.3454
# Epoch [5], Batch [200/938], Loss: 0.3423
# Epoch [5], Batch [300/938], Loss: 0.3387
# Epoch [5], Batch [400/938], Loss: 0.3311
# Epoch [5], Batch [500/938], Loss: 0.3420
# Epoch [5], Batch [600/938], Loss: 0.3434
# Epoch [5], Batch [700/938], Loss: 0.3351
# Epoch [5], Batch [800/938], Loss: 0.3332
# Epoch [5], Batch [900/938], Loss: 0.3186
# Epoch [6], Batch [100/938], Loss: 0.3131
# Epoch [6], Batch [200/938], Loss: 0.3266
# Epoch [6], Batch [300/938], Loss: 0.3238
# Epoch [6], Batch [400/938], Loss: 0.3164
# Epoch [6], Batch [500/938], Loss: 0.3215
# Epoch [6], Batch [600/938], Loss: 0.3316
# Epoch [6], Batch [700/938], Loss: 0.3043
# Epoch [6], Batch [800/938], Loss: 0.3285
# Epoch [6], Batch [900/938], Loss: 0.3224
# Epoch [7], Batch [100/938], Loss: 0.3123
# Epoch [7], Batch [200/938], Loss: 0.3068
# Epoch [7], Batch [300/938], Loss: 0.3219
# Epoch [7], Batch [400/938], Loss: 0.3133
# Epoch [7], Batch [500/938], Loss: 0.3001
# Epoch [7], Batch [600/938], Loss: 0.3103
# Epoch [7], Batch [700/938], Loss: 0.3096
# Epoch [7], Batch [800/938], Loss: 0.3052
# Epoch [7], Batch [900/938], Loss: 0.3111
# Epoch [8], Batch [100/938], Loss: 0.3096
# Epoch [8], Batch [200/938], Loss: 0.3142
# Epoch [8], Batch [300/938], Loss: 0.2831
# Epoch [8], Batch [400/938], Loss: 0.2938
# Epoch [8], Batch [500/938], Loss: 0.3039
# Epoch [8], Batch [600/938], Loss: 0.2993
# Epoch [8], Batch [700/938], Loss: 0.2981
# Epoch [8], Batch [800/938], Loss: 0.2902
# Epoch [8], Batch [900/938], Loss: 0.3045
# Epoch [9], Batch [100/938], Loss: 0.2899
# Epoch [9], Batch [200/938], Loss: 0.2920
# Epoch [9], Batch [300/938], Loss: 0.2833
# Epoch [9], Batch [400/938], Loss: 0.2761
# Epoch [9], Batch [500/938], Loss: 0.2896
# Epoch [9], Batch [600/938], Loss: 0.2948
# Epoch [9], Batch [700/938], Loss: 0.2925
# Epoch [9], Batch [800/938], Loss: 0.2945
# Epoch [9], Batch [900/938], Loss: 0.2968
# Epoch [10], Batch [100/938], Loss: 0.2883
# Epoch [10], Batch [200/938], Loss: 0.2673
# Epoch [10], Batch [300/938], Loss: 0.2904
# Epoch [10], Batch [400/938], Loss: 0.2799
# Epoch [10], Batch [500/938], Loss: 0.2764
# Epoch [10], Batch [600/938], Loss: 0.2860
# Epoch [10], Batch [700/938], Loss: 0.2779
# Epoch [10], Batch [800/938], Loss: 0.2825
# Epoch [10], Batch [900/938], Loss: 0.2749
# Accuracy for Configuration-8: 87.41%
#
# ..................................................
#
# Configuration - Configuration-9
# Input data:
# - Num Hidden Layers: 1
# - Hidden Layer Sizes: [128]
# - Batch Size: 64
# - Learning Rate: 0.001
# Epoch [1], Batch [100/938], Loss: 1.1574
# Epoch [1], Batch [200/938], Loss: 0.6670
# Epoch [1], Batch [300/938], Loss: 0.5880
# Epoch [1], Batch [400/938], Loss: 0.5295
# Epoch [1], Batch [500/938], Loss: 0.4997
# Epoch [1], Batch [600/938], Loss: 0.4752
# Epoch [1], Batch [700/938], Loss: 0.4716
# Epoch [1], Batch [800/938], Loss: 0.4516
# Epoch [1], Batch [900/938], Loss: 0.4360
# Epoch [2], Batch [100/938], Loss: 0.4287
# Epoch [2], Batch [200/938], Loss: 0.4142
# Epoch [2], Batch [300/938], Loss: 0.4089
# Epoch [2], Batch [400/938], Loss: 0.4019
# Epoch [2], Batch [500/938], Loss: 0.4005
# Epoch [2], Batch [600/938], Loss: 0.3866
# Epoch [2], Batch [700/938], Loss: 0.3915
# Epoch [2], Batch [800/938], Loss: 0.3793
# Epoch [2], Batch [900/938], Loss: 0.3856
# Epoch [3], Batch [100/938], Loss: 0.3768
# Epoch [3], Batch [200/938], Loss: 0.3617
# Epoch [3], Batch [300/938], Loss: 0.3577
# Epoch [3], Batch [400/938], Loss: 0.3625
# Epoch [3], Batch [500/938], Loss: 0.3524
# Epoch [3], Batch [600/938], Loss: 0.3691
# Epoch [3], Batch [700/938], Loss: 0.3477
# Epoch [3], Batch [800/938], Loss: 0.3716
# Epoch [3], Batch [900/938], Loss: 0.3470
# Epoch [4], Batch [100/938], Loss: 0.3491
# Epoch [4], Batch [200/938], Loss: 0.3316
# Epoch [4], Batch [300/938], Loss: 0.3411
# Epoch [4], Batch [400/938], Loss: 0.3432
# Epoch [4], Batch [500/938], Loss: 0.3362
# Epoch [4], Batch [600/938], Loss: 0.3362
# Epoch [4], Batch [700/938], Loss: 0.3311
# Epoch [4], Batch [800/938], Loss: 0.3326
# Epoch [4], Batch [900/938], Loss: 0.3158
# Epoch [5], Batch [100/938], Loss: 0.3267
# Epoch [5], Batch [200/938], Loss: 0.3127
# Epoch [5], Batch [300/938], Loss: 0.3015
# Epoch [5], Batch [400/938], Loss: 0.3141
# Epoch [5], Batch [500/938], Loss: 0.3203
# Epoch [5], Batch [600/938], Loss: 0.3164
# Epoch [5], Batch [700/938], Loss: 0.3102
# Epoch [5], Batch [800/938], Loss: 0.3227
# Epoch [5], Batch [900/938], Loss: 0.3089
# Epoch [6], Batch [100/938], Loss: 0.3000
# Epoch [6], Batch [200/938], Loss: 0.3113
# Epoch [6], Batch [300/938], Loss: 0.2959
# Epoch [6], Batch [400/938], Loss: 0.2875
# Epoch [6], Batch [500/938], Loss: 0.2933
# Epoch [6], Batch [600/938], Loss: 0.2856
# Epoch [6], Batch [700/938], Loss: 0.3063
# Epoch [6], Batch [800/938], Loss: 0.3095
# Epoch [6], Batch [900/938], Loss: 0.3163
# Epoch [7], Batch [100/938], Loss: 0.2800
# Epoch [7], Batch [200/938], Loss: 0.2743
# Epoch [7], Batch [300/938], Loss: 0.3025
# Epoch [7], Batch [400/938], Loss: 0.2988
# Epoch [7], Batch [500/938], Loss: 0.2907
# Epoch [7], Batch [600/938], Loss: 0.2662
# Epoch [7], Batch [700/938], Loss: 0.2701
# Epoch [7], Batch [800/938], Loss: 0.2875
# Epoch [7], Batch [900/938], Loss: 0.2781
# Epoch [8], Batch [100/938], Loss: 0.2762
# Epoch [8], Batch [200/938], Loss: 0.2736
# Epoch [8], Batch [300/938], Loss: 0.2730
# Epoch [8], Batch [400/938], Loss: 0.2838
# Epoch [8], Batch [500/938], Loss: 0.2599
# Epoch [8], Batch [600/938], Loss: 0.2751
# Epoch [8], Batch [700/938], Loss: 0.2732
# Epoch [8], Batch [800/938], Loss: 0.2622
# Epoch [8], Batch [900/938], Loss: 0.2850
# Epoch [9], Batch [100/938], Loss: 0.2494
# Epoch [9], Batch [200/938], Loss: 0.2475
# Epoch [9], Batch [300/938], Loss: 0.2711
# Epoch [9], Batch [400/938], Loss: 0.2702
# Epoch [9], Batch [500/938], Loss: 0.2773
# Epoch [9], Batch [600/938], Loss: 0.2539
# Epoch [9], Batch [700/938], Loss: 0.2719
# Epoch [9], Batch [800/938], Loss: 0.2598
# Epoch [9], Batch [900/938], Loss: 0.2518
# Epoch [10], Batch [100/938], Loss: 0.2493
# Epoch [10], Batch [200/938], Loss: 0.2511
# Epoch [10], Batch [300/938], Loss: 0.2454
# Epoch [10], Batch [400/938], Loss: 0.2566
# Epoch [10], Batch [500/938], Loss: 0.2576
# Epoch [10], Batch [600/938], Loss: 0.2572
# Epoch [10], Batch [700/938], Loss: 0.2390
# Epoch [10], Batch [800/938], Loss: 0.2481
# Epoch [10], Batch [900/938], Loss: 0.2625
# Accuracy for Configuration-9: 87.92%
#
# ..................................................
#
# Configuration - Configuration-10
# Input data:
# - Num Hidden Layers: 1
# - Hidden Layer Sizes: [256]
# - Batch Size: 64
# - Learning Rate: 0.001
# Epoch [1], Batch [100/938], Loss: 1.0064
# Epoch [1], Batch [200/938], Loss: 0.5938
# Epoch [1], Batch [300/938], Loss: 0.5557
# Epoch [1], Batch [400/938], Loss: 0.4903
# Epoch [1], Batch [500/938], Loss: 0.4707
# Epoch [1], Batch [600/938], Loss: 0.4675
# Epoch [1], Batch [700/938], Loss: 0.4521
# Epoch [1], Batch [800/938], Loss: 0.4365
# Epoch [1], Batch [900/938], Loss: 0.4406
# Epoch [2], Batch [100/938], Loss: 0.3963
# Epoch [2], Batch [200/938], Loss: 0.4133
# Epoch [2], Batch [300/938], Loss: 0.3966
# Epoch [2], Batch [400/938], Loss: 0.3960
# Epoch [2], Batch [500/938], Loss: 0.3878
# Epoch [2], Batch [600/938], Loss: 0.3757
# Epoch [2], Batch [700/938], Loss: 0.3764
# Epoch [2], Batch [800/938], Loss: 0.3811
# Epoch [2], Batch [900/938], Loss: 0.3776
# Epoch [3], Batch [100/938], Loss: 0.3620
# Epoch [3], Batch [200/938], Loss: 0.3682
# Epoch [3], Batch [300/938], Loss: 0.3439
# Epoch [3], Batch [400/938], Loss: 0.3462
# Epoch [3], Batch [500/938], Loss: 0.3272
# Epoch [3], Batch [600/938], Loss: 0.3569
# Epoch [3], Batch [700/938], Loss: 0.3428
# Epoch [3], Batch [800/938], Loss: 0.3624
# Epoch [3], Batch [900/938], Loss: 0.3347
# Epoch [4], Batch [100/938], Loss: 0.3192
# Epoch [4], Batch [200/938], Loss: 0.3268
# Epoch [4], Batch [300/938], Loss: 0.3274
# Epoch [4], Batch [400/938], Loss: 0.3286
# Epoch [4], Batch [500/938], Loss: 0.3199
# Epoch [4], Batch [600/938], Loss: 0.3220
# Epoch [4], Batch [700/938], Loss: 0.3164
# Epoch [4], Batch [800/938], Loss: 0.3062
# Epoch [4], Batch [900/938], Loss: 0.3297
# Epoch [5], Batch [100/938], Loss: 0.3215
# Epoch [5], Batch [200/938], Loss: 0.3130
# Epoch [5], Batch [300/938], Loss: 0.3063
# Epoch [5], Batch [400/938], Loss: 0.2923
# Epoch [5], Batch [500/938], Loss: 0.3087
# Epoch [5], Batch [600/938], Loss: 0.2866
# Epoch [5], Batch [700/938], Loss: 0.2965
# Epoch [5], Batch [800/938], Loss: 0.2977
# Epoch [5], Batch [900/938], Loss: 0.2948
# Epoch [6], Batch [100/938], Loss: 0.2851
# Epoch [6], Batch [200/938], Loss: 0.2932
# Epoch [6], Batch [300/938], Loss: 0.2776
# Epoch [6], Batch [400/938], Loss: 0.2920
# Epoch [6], Batch [500/938], Loss: 0.2734
# Epoch [6], Batch [600/938], Loss: 0.2964
# Epoch [6], Batch [700/938], Loss: 0.2795
# Epoch [6], Batch [800/938], Loss: 0.2621
# Epoch [6], Batch [900/938], Loss: 0.2836
# Epoch [7], Batch [100/938], Loss: 0.2573
# Epoch [7], Batch [200/938], Loss: 0.2668
# Epoch [7], Batch [300/938], Loss: 0.2691
# Epoch [7], Batch [400/938], Loss: 0.2706
# Epoch [7], Batch [500/938], Loss: 0.2712
# Epoch [7], Batch [600/938], Loss: 0.2788
# Epoch [7], Batch [700/938], Loss: 0.2655
# Epoch [7], Batch [800/938], Loss: 0.2584
# Epoch [7], Batch [900/938], Loss: 0.2639
# Epoch [8], Batch [100/938], Loss: 0.2542
# Epoch [8], Batch [200/938], Loss: 0.2489
# Epoch [8], Batch [300/938], Loss: 0.2553
# Epoch [8], Batch [400/938], Loss: 0.2539
# Epoch [8], Batch [500/938], Loss: 0.2476
# Epoch [8], Batch [600/938], Loss: 0.2554
# Epoch [8], Batch [700/938], Loss: 0.2686
# Epoch [8], Batch [800/938], Loss: 0.2504
# Epoch [8], Batch [900/938], Loss: 0.2640
# Epoch [9], Batch [100/938], Loss: 0.2526
# Epoch [9], Batch [200/938], Loss: 0.2334
# Epoch [9], Batch [300/938], Loss: 0.2479
# Epoch [9], Batch [400/938], Loss: 0.2306
# Epoch [9], Batch [500/938], Loss: 0.2382
# Epoch [9], Batch [600/938], Loss: 0.2397
# Epoch [9], Batch [700/938], Loss: 0.2435
# Epoch [9], Batch [800/938], Loss: 0.2377
# Epoch [9], Batch [900/938], Loss: 0.2570
# Epoch [10], Batch [100/938], Loss: 0.2379
# Epoch [10], Batch [200/938], Loss: 0.2131
# Epoch [10], Batch [300/938], Loss: 0.2227
# Epoch [10], Batch [400/938], Loss: 0.2481
# Epoch [10], Batch [500/938], Loss: 0.2391
# Epoch [10], Batch [600/938], Loss: 0.2221
# Epoch [10], Batch [700/938], Loss: 0.2320
# Epoch [10], Batch [800/938], Loss: 0.2407
# Epoch [10], Batch [900/938], Loss: 0.2372
# Accuracy for Configuration-10: 87.59%
#
# ..................................................
#
# Configuration - Configuration-11
# Input data:
# - Num Hidden Layers: 3
# - Hidden Layer Sizes: [32, 64, 128]
# - Batch Size: 128
# - Learning Rate: 0.001
# Epoch [1], Batch [100/938], Loss: 1.8350
# Epoch [1], Batch [200/938], Loss: 1.4774
# Epoch [1], Batch [300/938], Loss: 1.2719
# Epoch [1], Batch [400/938], Loss: 1.1355
# Epoch [1], Batch [500/938], Loss: 1.0321
# Epoch [1], Batch [600/938], Loss: 0.9338
# Epoch [1], Batch [700/938], Loss: 0.8622
# Epoch [1], Batch [800/938], Loss: 0.8283
# Epoch [1], Batch [900/938], Loss: 0.8038
# Epoch [2], Batch [100/938], Loss: 0.7436
# Epoch [2], Batch [200/938], Loss: 0.7239
# Epoch [2], Batch [300/938], Loss: 0.7135
# Epoch [2], Batch [400/938], Loss: 0.6921
# Epoch [2], Batch [500/938], Loss: 0.7020
# Epoch [2], Batch [600/938], Loss: 0.6731
# Epoch [2], Batch [700/938], Loss: 0.6689
# Epoch [2], Batch [800/938], Loss: 0.6449
# Epoch [2], Batch [900/938], Loss: 0.6406
# Epoch [3], Batch [100/938], Loss: 0.5877
# Epoch [3], Batch [200/938], Loss: 0.5800
# Epoch [3], Batch [300/938], Loss: 0.5615
# Epoch [3], Batch [400/938], Loss: 0.5661
# Epoch [3], Batch [500/938], Loss: 0.5258
# Epoch [3], Batch [600/938], Loss: 0.5155
# Epoch [3], Batch [700/938], Loss: 0.5330
# Epoch [3], Batch [800/938], Loss: 0.5139
# Epoch [3], Batch [900/938], Loss: 0.5043
# Epoch [4], Batch [100/938], Loss: 0.4793
# Epoch [4], Batch [200/938], Loss: 0.4923
# Epoch [4], Batch [300/938], Loss: 0.4816
# Epoch [4], Batch [400/938], Loss: 0.4568
# Epoch [4], Batch [500/938], Loss: 0.4591
# Epoch [4], Batch [600/938], Loss: 0.4370
# Epoch [4], Batch [700/938], Loss: 0.4270
# Epoch [4], Batch [800/938], Loss: 0.4520
# Epoch [4], Batch [900/938], Loss: 0.4350
# Epoch [5], Batch [100/938], Loss: 0.4175
# Epoch [5], Batch [200/938], Loss: 0.4228
# Epoch [5], Batch [300/938], Loss: 0.4089
# Epoch [5], Batch [400/938], Loss: 0.4220
# Epoch [5], Batch [500/938], Loss: 0.4196
# Epoch [5], Batch [600/938], Loss: 0.4062
# Epoch [5], Batch [700/938], Loss: 0.4326
# Epoch [5], Batch [800/938], Loss: 0.4180
# Epoch [5], Batch [900/938], Loss: 0.4038
# Epoch [6], Batch [100/938], Loss: 0.3986
# Epoch [6], Batch [200/938], Loss: 0.3762
# Epoch [6], Batch [300/938], Loss: 0.4118
# Epoch [6], Batch [400/938], Loss: 0.4007
# Epoch [6], Batch [500/938], Loss: 0.4028
# Epoch [6], Batch [600/938], Loss: 0.3945
# Epoch [6], Batch [700/938], Loss: 0.4035
# Epoch [6], Batch [800/938], Loss: 0.3791
# Epoch [6], Batch [900/938], Loss: 0.3839
# Epoch [7], Batch [100/938], Loss: 0.3720
# Epoch [7], Batch [200/938], Loss: 0.3813
# Epoch [7], Batch [300/938], Loss: 0.3846
# Epoch [7], Batch [400/938], Loss: 0.3597
# Epoch [7], Batch [500/938], Loss: 0.3720
# Epoch [7], Batch [600/938], Loss: 0.3934
# Epoch [7], Batch [700/938], Loss: 0.3745
# Epoch [7], Batch [800/938], Loss: 0.3804
# Epoch [7], Batch [900/938], Loss: 0.3681
# Epoch [8], Batch [100/938], Loss: 0.3671
# Epoch [8], Batch [200/938], Loss: 0.3539
# Epoch [8], Batch [300/938], Loss: 0.3610
# Epoch [8], Batch [400/938], Loss: 0.3779
# Epoch [8], Batch [500/938], Loss: 0.3717
# Epoch [8], Batch [600/938], Loss: 0.3615
# Epoch [8], Batch [700/938], Loss: 0.3656
# Epoch [8], Batch [800/938], Loss: 0.3582
# Epoch [8], Batch [900/938], Loss: 0.3640
# Epoch [9], Batch [100/938], Loss: 0.3513
# Epoch [9], Batch [200/938], Loss: 0.3451
# Epoch [9], Batch [300/938], Loss: 0.3495
# Epoch [9], Batch [400/938], Loss: 0.3371
# Epoch [9], Batch [500/938], Loss: 0.3548
# Epoch [9], Batch [600/938], Loss: 0.3576
# Epoch [9], Batch [700/938], Loss: 0.3736
# Epoch [9], Batch [800/938], Loss: 0.3494
# Epoch [9], Batch [900/938], Loss: 0.3609
# Epoch [10], Batch [100/938], Loss: 0.3407
# Epoch [10], Batch [200/938], Loss: 0.3518
# Epoch [10], Batch [300/938], Loss: 0.3840
# Epoch [10], Batch [400/938], Loss: 0.3267
# Epoch [10], Batch [500/938], Loss: 0.3544
# Epoch [10], Batch [600/938], Loss: 0.3434
# Epoch [10], Batch [700/938], Loss: 0.3475
# Epoch [10], Batch [800/938], Loss: 0.3388
# Epoch [10], Batch [900/938], Loss: 0.3378
# Accuracy for Configuration-11: 85.86%
#
# ..................................................
#
# Configuration - Configuration-12
# Input data:
# - Num Hidden Layers: 4
# - Hidden Layer Sizes: [64, 128, 256, 512]
# - Batch Size: 128
# - Learning Rate: 0.001
# Epoch [1], Batch [100/938], Loss: 2.0985
# Epoch [1], Batch [200/938], Loss: 1.4503
# Epoch [1], Batch [300/938], Loss: 1.1066
# Epoch [1], Batch [400/938], Loss: 0.8991
# Epoch [1], Batch [500/938], Loss: 0.8033
# Epoch [1], Batch [600/938], Loss: 0.7465
# Epoch [1], Batch [700/938], Loss: 0.7180
# Epoch [1], Batch [800/938], Loss: 0.6476
# Epoch [1], Batch [900/938], Loss: 0.6451
# Epoch [2], Batch [100/938], Loss: 0.6078
# Epoch [2], Batch [200/938], Loss: 0.5889
# Epoch [2], Batch [300/938], Loss: 0.5620
# Epoch [2], Batch [400/938], Loss: 0.5469
# Epoch [2], Batch [500/938], Loss: 0.5509
# Epoch [2], Batch [600/938], Loss: 0.5322
# Epoch [2], Batch [700/938], Loss: 0.5314
# Epoch [2], Batch [800/938], Loss: 0.5230
# Epoch [2], Batch [900/938], Loss: 0.5374
# Epoch [3], Batch [100/938], Loss: 0.4798
# Epoch [3], Batch [200/938], Loss: 0.4819
# Epoch [3], Batch [300/938], Loss: 0.4787
# Epoch [3], Batch [400/938], Loss: 0.4903
# Epoch [3], Batch [500/938], Loss: 0.4682
# Epoch [3], Batch [600/938], Loss: 0.4493
# Epoch [3], Batch [700/938], Loss: 0.4696
# Epoch [3], Batch [800/938], Loss: 0.4527
# Epoch [3], Batch [900/938], Loss: 0.4341
# Epoch [4], Batch [100/938], Loss: 0.4199
# Epoch [4], Batch [200/938], Loss: 0.4237
# Epoch [4], Batch [300/938], Loss: 0.4201
# Epoch [4], Batch [400/938], Loss: 0.4244
# Epoch [4], Batch [500/938], Loss: 0.4242
# Epoch [4], Batch [600/938], Loss: 0.4124
# Epoch [4], Batch [700/938], Loss: 0.4222
# Epoch [4], Batch [800/938], Loss: 0.4142
# Epoch [4], Batch [900/938], Loss: 0.4287
# Epoch [5], Batch [100/938], Loss: 0.4081
# Epoch [5], Batch [200/938], Loss: 0.3972
# Epoch [5], Batch [300/938], Loss: 0.3943
# Epoch [5], Batch [400/938], Loss: 0.3853
# Epoch [5], Batch [500/938], Loss: 0.3884
# Epoch [5], Batch [600/938], Loss: 0.3784
# Epoch [5], Batch [700/938], Loss: 0.3862
# Epoch [5], Batch [800/938], Loss: 0.3868
# Epoch [5], Batch [900/938], Loss: 0.4063
# Epoch [6], Batch [100/938], Loss: 0.3833
# Epoch [6], Batch [200/938], Loss: 0.3809
# Epoch [6], Batch [300/938], Loss: 0.3755
# Epoch [6], Batch [400/938], Loss: 0.3681
# Epoch [6], Batch [500/938], Loss: 0.3644
# Epoch [6], Batch [600/938], Loss: 0.3746
# Epoch [6], Batch [700/938], Loss: 0.3862
# Epoch [6], Batch [800/938], Loss: 0.3676
# Epoch [6], Batch [900/938], Loss: 0.3449
# Epoch [7], Batch [100/938], Loss: 0.3495
# Epoch [7], Batch [200/938], Loss: 0.3367
# Epoch [7], Batch [300/938], Loss: 0.3633
# Epoch [7], Batch [400/938], Loss: 0.3705
# Epoch [7], Batch [500/938], Loss: 0.3579
# Epoch [7], Batch [600/938], Loss: 0.3758
# Epoch [7], Batch [700/938], Loss: 0.3511
# Epoch [7], Batch [800/938], Loss: 0.3727
# Epoch [7], Batch [900/938], Loss: 0.3560
# Epoch [8], Batch [100/938], Loss: 0.3456
# Epoch [8], Batch [200/938], Loss: 0.3265
# Epoch [8], Batch [300/938], Loss: 0.3383
# Epoch [8], Batch [400/938], Loss: 0.3350
# Epoch [8], Batch [500/938], Loss: 0.3374
# Epoch [8], Batch [600/938], Loss: 0.3500
# Epoch [8], Batch [700/938], Loss: 0.3432
# Epoch [8], Batch [800/938], Loss: 0.3472
# Epoch [8], Batch [900/938], Loss: 0.3580
# Epoch [9], Batch [100/938], Loss: 0.3502
# Epoch [9], Batch [200/938], Loss: 0.3195
# Epoch [9], Batch [300/938], Loss: 0.3237
# Epoch [9], Batch [400/938], Loss: 0.3357
# Epoch [9], Batch [500/938], Loss: 0.3361
# Epoch [9], Batch [600/938], Loss: 0.3214
# Epoch [9], Batch [700/938], Loss: 0.3254
# Epoch [9], Batch [800/938], Loss: 0.3388
# Epoch [9], Batch [900/938], Loss: 0.3329
# Epoch [10], Batch [100/938], Loss: 0.3235
# Epoch [10], Batch [200/938], Loss: 0.3196
# Epoch [10], Batch [300/938], Loss: 0.3271
# Epoch [10], Batch [400/938], Loss: 0.3284
# Epoch [10], Batch [500/938], Loss: 0.3012
# Epoch [10], Batch [600/938], Loss: 0.3495
# Epoch [10], Batch [700/938], Loss: 0.3300
# Epoch [10], Batch [800/938], Loss: 0.3290
# Epoch [10], Batch [900/938], Loss: 0.3170
# Accuracy for Configuration-12: 85.75%
#
# ..................................................
#
# Configuration - Configuration-13
# Input data:
# - Num Hidden Layers: 2
# - Hidden Layer Sizes: [128, 256]
# - Batch Size: 256
# - Learning Rate: 0.001
# Epoch [1], Batch [100/938], Loss: 1.1174
# Epoch [1], Batch [200/938], Loss: 0.7010
# Epoch [1], Batch [300/938], Loss: 0.6004
# Epoch [1], Batch [400/938], Loss: 0.5574
# Epoch [1], Batch [500/938], Loss: 0.5194
# Epoch [1], Batch [600/938], Loss: 0.4831
# Epoch [1], Batch [700/938], Loss: 0.4626
# Epoch [1], Batch [800/938], Loss: 0.4608
# Epoch [1], Batch [900/938], Loss: 0.4622
# Epoch [2], Batch [100/938], Loss: 0.4318
# Epoch [2], Batch [200/938], Loss: 0.4240
# Epoch [2], Batch [300/938], Loss: 0.4180
# Epoch [2], Batch [400/938], Loss: 0.4196
# Epoch [2], Batch [500/938], Loss: 0.4115
# Epoch [2], Batch [600/938], Loss: 0.3773
# Epoch [2], Batch [700/938], Loss: 0.3868
# Epoch [2], Batch [800/938], Loss: 0.3976
# Epoch [2], Batch [900/938], Loss: 0.3813
# Epoch [3], Batch [100/938], Loss: 0.3531
# Epoch [3], Batch [200/938], Loss: 0.3571
# Epoch [3], Batch [300/938], Loss: 0.3639
# Epoch [3], Batch [400/938], Loss: 0.3759
# Epoch [3], Batch [500/938], Loss: 0.3536
# Epoch [3], Batch [600/938], Loss: 0.3452
# Epoch [3], Batch [700/938], Loss: 0.3812
# Epoch [3], Batch [800/938], Loss: 0.3593
# Epoch [3], Batch [900/938], Loss: 0.3550
# Epoch [4], Batch [100/938], Loss: 0.3466
# Epoch [4], Batch [200/938], Loss: 0.3315
# Epoch [4], Batch [300/938], Loss: 0.3338
# Epoch [4], Batch [400/938], Loss: 0.3272
# Epoch [4], Batch [500/938], Loss: 0.3626
# Epoch [4], Batch [600/938], Loss: 0.3445
# Epoch [4], Batch [700/938], Loss: 0.3218
# Epoch [4], Batch [800/938], Loss: 0.3296
# Epoch [4], Batch [900/938], Loss: 0.3193
# Epoch [5], Batch [100/938], Loss: 0.3187
# Epoch [5], Batch [200/938], Loss: 0.3078
# Epoch [5], Batch [300/938], Loss: 0.3057
# Epoch [5], Batch [400/938], Loss: 0.3086
# Epoch [5], Batch [500/938], Loss: 0.3155
# Epoch [5], Batch [600/938], Loss: 0.3066
# Epoch [5], Batch [700/938], Loss: 0.3251
# Epoch [5], Batch [800/938], Loss: 0.3171
# Epoch [5], Batch [900/938], Loss: 0.3227
# Epoch [6], Batch [100/938], Loss: 0.3049
# Epoch [6], Batch [200/938], Loss: 0.3015
# Epoch [6], Batch [300/938], Loss: 0.3109
# Epoch [6], Batch [400/938], Loss: 0.2954
# Epoch [6], Batch [500/938], Loss: 0.2816
# Epoch [6], Batch [600/938], Loss: 0.3007
# Epoch [6], Batch [700/938], Loss: 0.3046
# Epoch [6], Batch [800/938], Loss: 0.2999
# Epoch [6], Batch [900/938], Loss: 0.2894
# Epoch [7], Batch [100/938], Loss: 0.2801
# Epoch [7], Batch [200/938], Loss: 0.2864
# Epoch [7], Batch [300/938], Loss: 0.2806
# Epoch [7], Batch [400/938], Loss: 0.2896
# Epoch [7], Batch [500/938], Loss: 0.2881
# Epoch [7], Batch [600/938], Loss: 0.2941
# Epoch [7], Batch [700/938], Loss: 0.2839
# Epoch [7], Batch [800/938], Loss: 0.2694
# Epoch [7], Batch [900/938], Loss: 0.2887
# Epoch [8], Batch [100/938], Loss: 0.2616
# Epoch [8], Batch [200/938], Loss: 0.2808
# Epoch [8], Batch [300/938], Loss: 0.2641
# Epoch [8], Batch [400/938], Loss: 0.2737
# Epoch [8], Batch [500/938], Loss: 0.2706
# Epoch [8], Batch [600/938], Loss: 0.2738
# Epoch [8], Batch [700/938], Loss: 0.2727
# Epoch [8], Batch [800/938], Loss: 0.2655
# Epoch [8], Batch [900/938], Loss: 0.2850
# Epoch [9], Batch [100/938], Loss: 0.2699
# Epoch [9], Batch [200/938], Loss: 0.2555
# Epoch [9], Batch [300/938], Loss: 0.2524
# Epoch [9], Batch [400/938], Loss: 0.2588
# Epoch [9], Batch [500/938], Loss: 0.2826
# Epoch [9], Batch [600/938], Loss: 0.2677
# Epoch [9], Batch [700/938], Loss: 0.2682
# Epoch [9], Batch [800/938], Loss: 0.2513
# Epoch [9], Batch [900/938], Loss: 0.2569
# Epoch [10], Batch [100/938], Loss: 0.2477
# Epoch [10], Batch [200/938], Loss: 0.2529
# Epoch [10], Batch [300/938], Loss: 0.2504
# Epoch [10], Batch [400/938], Loss: 0.2514
# Epoch [10], Batch [500/938], Loss: 0.2577
# Epoch [10], Batch [600/938], Loss: 0.2548
# Epoch [10], Batch [700/938], Loss: 0.2597
# Epoch [10], Batch [800/938], Loss: 0.2641
# Epoch [10], Batch [900/938], Loss: 0.2543
# Accuracy for Configuration-13: 87.98%
#
# ..................................................
#
# Configuration - Configuration-14
# Input data:
# - Num Hidden Layers: 1
# - Hidden Layer Sizes: [512]
# - Batch Size: 256
# - Learning Rate: 0.001
# Epoch [1], Batch [100/938], Loss: 0.9049
# Epoch [1], Batch [200/938], Loss: 0.5633
# Epoch [1], Batch [300/938], Loss: 0.5360
# Epoch [1], Batch [400/938], Loss: 0.4821
# Epoch [1], Batch [500/938], Loss: 0.4677
# Epoch [1], Batch [600/938], Loss: 0.4433
# Epoch [1], Batch [700/938], Loss: 0.4329
# Epoch [1], Batch [800/938], Loss: 0.4341
# Epoch [1], Batch [900/938], Loss: 0.4404
# Epoch [2], Batch [100/938], Loss: 0.4044
# Epoch [2], Batch [200/938], Loss: 0.3959
# Epoch [2], Batch [300/938], Loss: 0.3911
# Epoch [2], Batch [400/938], Loss: 0.3940
# Epoch [2], Batch [500/938], Loss: 0.3810
# Epoch [2], Batch [600/938], Loss: 0.3732
# Epoch [2], Batch [700/938], Loss: 0.3651
# Epoch [2], Batch [800/938], Loss: 0.3689
# Epoch [2], Batch [900/938], Loss: 0.3760
# Epoch [3], Batch [100/938], Loss: 0.3614
# Epoch [3], Batch [200/938], Loss: 0.3295
# Epoch [3], Batch [300/938], Loss: 0.3367
# Epoch [3], Batch [400/938], Loss: 0.3515
# Epoch [3], Batch [500/938], Loss: 0.3372
# Epoch [3], Batch [600/938], Loss: 0.3464
# Epoch [3], Batch [700/938], Loss: 0.3505
# Epoch [3], Batch [800/938], Loss: 0.3344
# Epoch [3], Batch [900/938], Loss: 0.3425
# Epoch [4], Batch [100/938], Loss: 0.3186
# Epoch [4], Batch [200/938], Loss: 0.3269
# Epoch [4], Batch [300/938], Loss: 0.3400
# Epoch [4], Batch [400/938], Loss: 0.3098
# Epoch [4], Batch [500/938], Loss: 0.3076
# Epoch [4], Batch [600/938], Loss: 0.3170
# Epoch [4], Batch [700/938], Loss: 0.3064
# Epoch [4], Batch [800/938], Loss: 0.2937
# Epoch [4], Batch [900/938], Loss: 0.3015
# Epoch [5], Batch [100/938], Loss: 0.2859
# Epoch [5], Batch [200/938], Loss: 0.3064
# Epoch [5], Batch [300/938], Loss: 0.2926
# Epoch [5], Batch [400/938], Loss: 0.3013
# Epoch [5], Batch [500/938], Loss: 0.2871
# Epoch [5], Batch [600/938], Loss: 0.2876
# Epoch [5], Batch [700/938], Loss: 0.2887
# Epoch [5], Batch [800/938], Loss: 0.2951
# Epoch [5], Batch [900/938], Loss: 0.2777
# Epoch [6], Batch [100/938], Loss: 0.2689
# Epoch [6], Batch [200/938], Loss: 0.2694
# Epoch [6], Batch [300/938], Loss: 0.2861
# Epoch [6], Batch [400/938], Loss: 0.2758
# Epoch [6], Batch [500/938], Loss: 0.2651
# Epoch [6], Batch [600/938], Loss: 0.2800
# Epoch [6], Batch [700/938], Loss: 0.2710
# Epoch [6], Batch [800/938], Loss: 0.2732
# Epoch [6], Batch [900/938], Loss: 0.2681
# Epoch [7], Batch [100/938], Loss: 0.2482
# Epoch [7], Batch [200/938], Loss: 0.2512
# Epoch [7], Batch [300/938], Loss: 0.2685
# Epoch [7], Batch [400/938], Loss: 0.2493
# Epoch [7], Batch [500/938], Loss: 0.2582
# Epoch [7], Batch [600/938], Loss: 0.2472
# Epoch [7], Batch [700/938], Loss: 0.2647
# Epoch [7], Batch [800/938], Loss: 0.2587
# Epoch [7], Batch [900/938], Loss: 0.2630
# Epoch [8], Batch [100/938], Loss: 0.2436
# Epoch [8], Batch [200/938], Loss: 0.2557
# Epoch [8], Batch [300/938], Loss: 0.2406
# Epoch [8], Batch [400/938], Loss: 0.2420
# Epoch [8], Batch [500/938], Loss: 0.2393
# Epoch [8], Batch [600/938], Loss: 0.2270
# Epoch [8], Batch [700/938], Loss: 0.2439
# Epoch [8], Batch [800/938], Loss: 0.2420
# Epoch [8], Batch [900/938], Loss: 0.2492
# Epoch [9], Batch [100/938], Loss: 0.2287
# Epoch [9], Batch [200/938], Loss: 0.2327
# Epoch [9], Batch [300/938], Loss: 0.2237
# Epoch [9], Batch [400/938], Loss: 0.2337
# Epoch [9], Batch [500/938], Loss: 0.2351
# Epoch [9], Batch [600/938], Loss: 0.2377
# Epoch [9], Batch [700/938], Loss: 0.2214
# Epoch [9], Batch [800/938], Loss: 0.2227
# Epoch [9], Batch [900/938], Loss: 0.2322
# Epoch [10], Batch [100/938], Loss: 0.2222
# Epoch [10], Batch [200/938], Loss: 0.2146
# Epoch [10], Batch [300/938], Loss: 0.2092
# Epoch [10], Batch [400/938], Loss: 0.2101
# Epoch [10], Batch [500/938], Loss: 0.2204
# Epoch [10], Batch [600/938], Loss: 0.2180
# Epoch [10], Batch [700/938], Loss: 0.2207
# Epoch [10], Batch [800/938], Loss: 0.2155
# Epoch [10], Batch [900/938], Loss: 0.2259
# Accuracy for Configuration-14: 88.76%
#
# ..................................................
#
# Configuration - Configuration-15
# Input data:
# - Num Hidden Layers: 4
# - Hidden Layer Sizes: [64, 128, 256, 512]
# - Batch Size: 32
# - Learning Rate: 0.001
# Epoch [1], Batch [100/938], Loss: 1.7930
# Epoch [1], Batch [200/938], Loss: 1.2091
# Epoch [1], Batch [300/938], Loss: 0.9837
# Epoch [1], Batch [400/938], Loss: 0.8913
# Epoch [1], Batch [500/938], Loss: 0.8403
# Epoch [1], Batch [600/938], Loss: 0.7832
# Epoch [1], Batch [700/938], Loss: 0.7585
# Epoch [1], Batch [800/938], Loss: 0.7373
# Epoch [1], Batch [900/938], Loss: 0.7106
# Epoch [2], Batch [100/938], Loss: 0.6760
# Epoch [2], Batch [200/938], Loss: 0.6636
# Epoch [2], Batch [300/938], Loss: 0.6523
# Epoch [2], Batch [400/938], Loss: 0.6318
# Epoch [2], Batch [500/938], Loss: 0.5913
# Epoch [2], Batch [600/938], Loss: 0.5952
# Epoch [2], Batch [700/938], Loss: 0.5934
# Epoch [2], Batch [800/938], Loss: 0.5423
# Epoch [2], Batch [900/938], Loss: 0.5716
# Epoch [3], Batch [100/938], Loss: 0.5265
# Epoch [3], Batch [200/938], Loss: 0.5365
# Epoch [3], Batch [300/938], Loss: 0.4981
# Epoch [3], Batch [400/938], Loss: 0.5082
# Epoch [3], Batch [500/938], Loss: 0.5014
# Epoch [3], Batch [600/938], Loss: 0.4851
# Epoch [3], Batch [700/938], Loss: 0.4727
# Epoch [3], Batch [800/938], Loss: 0.5020
# Epoch [3], Batch [900/938], Loss: 0.4678
# Epoch [4], Batch [100/938], Loss: 0.4546
# Epoch [4], Batch [200/938], Loss: 0.4521
# Epoch [4], Batch [300/938], Loss: 0.4709
# Epoch [4], Batch [400/938], Loss: 0.4540
# Epoch [4], Batch [500/938], Loss: 0.4519
# Epoch [4], Batch [600/938], Loss: 0.4408
# Epoch [4], Batch [700/938], Loss: 0.4276
# Epoch [4], Batch [800/938], Loss: 0.4379
# Epoch [4], Batch [900/938], Loss: 0.4503
# Epoch [5], Batch [100/938], Loss: 0.4118
# Epoch [5], Batch [200/938], Loss: 0.4238
# Epoch [5], Batch [300/938], Loss: 0.4201
# Epoch [5], Batch [400/938], Loss: 0.4370
# Epoch [5], Batch [500/938], Loss: 0.4159
# Epoch [5], Batch [600/938], Loss: 0.4079
# Epoch [5], Batch [700/938], Loss: 0.4368
# Epoch [5], Batch [800/938], Loss: 0.3858
# Epoch [5], Batch [900/938], Loss: 0.4068
# Epoch [6], Batch [100/938], Loss: 0.3867
# Epoch [6], Batch [200/938], Loss: 0.3888
# Epoch [6], Batch [300/938], Loss: 0.3994
# Epoch [6], Batch [400/938], Loss: 0.3907
# Epoch [6], Batch [500/938], Loss: 0.3976
# Epoch [6], Batch [600/938], Loss: 0.3961
# Epoch [6], Batch [700/938], Loss: 0.3929
# Epoch [6], Batch [800/938], Loss: 0.4058
# Epoch [6], Batch [900/938], Loss: 0.3732
# Epoch [7], Batch [100/938], Loss: 0.3770
# Epoch [7], Batch [200/938], Loss: 0.3781
# Epoch [7], Batch [300/938], Loss: 0.3878
# Epoch [7], Batch [400/938], Loss: 0.3759
# Epoch [7], Batch [500/938], Loss: 0.3683
# Epoch [7], Batch [600/938], Loss: 0.3661
# Epoch [7], Batch [700/938], Loss: 0.3700
# Epoch [7], Batch [800/938], Loss: 0.3688
# Epoch [7], Batch [900/938], Loss: 0.3813
# Epoch [8], Batch [100/938], Loss: 0.3676
# Epoch [8], Batch [200/938], Loss: 0.3545
# Epoch [8], Batch [300/938], Loss: 0.3466
# Epoch [8], Batch [400/938], Loss: 0.3459
# Epoch [8], Batch [500/938], Loss: 0.3693
# Epoch [8], Batch [600/938], Loss: 0.3473
# Epoch [8], Batch [700/938], Loss: 0.3551
# Epoch [8], Batch [800/938], Loss: 0.3738
# Epoch [8], Batch [900/938], Loss: 0.3643
# Epoch [9], Batch [100/938], Loss: 0.3499
# Epoch [9], Batch [200/938], Loss: 0.3561
# Epoch [9], Batch [300/938], Loss: 0.3385
# Epoch [9], Batch [400/938], Loss: 0.3502
# Epoch [9], Batch [500/938], Loss: 0.3524
# Epoch [9], Batch [600/938], Loss: 0.3421
# Epoch [9], Batch [700/938], Loss: 0.3563
# Epoch [9], Batch [800/938], Loss: 0.3404
# Epoch [9], Batch [900/938], Loss: 0.3443
# Epoch [10], Batch [100/938], Loss: 0.3210
# Epoch [10], Batch [200/938], Loss: 0.3362
# Epoch [10], Batch [300/938], Loss: 0.3491
# Epoch [10], Batch [400/938], Loss: 0.3256
# Epoch [10], Batch [500/938], Loss: 0.3420
# Epoch [10], Batch [600/938], Loss: 0.3201
# Epoch [10], Batch [700/938], Loss: 0.3205
# Epoch [10], Batch [800/938], Loss: 0.3411
# Epoch [10], Batch [900/938], Loss: 0.3595
# Accuracy for Configuration-15: 85.80%
#
# ..................................................
#
# Configuration       Num Hidden Layers  Hidden Layer Sizes      Batch Size    Learning Rate    Accuracy
# ----------------  -------------------  --------------------  ------------  ---------------  ----------
# Configuration-1                     3  [32, 64, 128]                   64             0.00        0.86
# Configuration-2                     3  [64, 128, 256]                 512             0.00        0.84
# Configuration-3                     3  [128, 256, 512]                 64             0.00        0.88
# Configuration-4                     2  [64, 128]                       64             0.00        0.88
# Configuration-5                     2  [32, 64]                        64             0.00        0.86
# Configuration-6                     2  [128, 256]                      64             0.00        0.88
# Configuration-7                     2  [256, 512]                      64             0.00        0.88
# Configuration-8                     1  [64]                            64             0.00        0.87
# Configuration-9                     1  [128]                           64             0.00        0.88
# Configuration-10                    1  [256]                           64             0.00        0.88
# Configuration-11                    3  [32, 64, 128]                  128             0.00        0.86
# Configuration-12                    4  [64, 128, 256, 512]            128             0.00        0.86
# Configuration-13                    2  [128, 256]                     256             0.00        0.88
# Configuration-14                    1  [512]                          256             0.00        0.89
# Configuration-15                    4  [64, 128, 256, 512]             32             0.00        0.86

# %%
# Extract configurations and accuracies for plotting
configs = [result[0] for result in FC_results]
accuracies = [result[5] * 100 for result in FC_results]

# Plotting accuracy vs configurations
plt.figure(figsize=(10, 6))
bars = plt.bar(range(1, len(configs) + 1), accuracies, color='skyblue')
plt.xlabel('Configuration')
plt.ylabel('Accuracy (%)')  # Updated ylabel to show percentage
plt.title('Accuracy vs Configurations')
plt.xticks(range(1, len(configs) + 1), range(1, len(configs) + 1), rotation=45, ha='right')
plt.ylim(0, 100)  # Setting y-axis limit from 0 to 100 for percentage
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adding text inside the bars
for bar, accuracy in zip(bars, accuracies):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() - 5, f'{accuracy:.2f}%',
             ha='center', va='bottom', color='black', fontsize=7)

plt.tight_layout()
plt.show()

# %%
sorted_results = sorted(FC_results, key=lambda x: x[5], reverse=True)
top_5_results = sorted_results[:5]

# Extract configurations and accuracies for plotting
top_5_configs = [result[0] for result in top_5_results]
top_5_accuracies = [result[5] * 100 for result in top_5_results]

# Plotting top 5 accuracies
plt.figure(figsize=(10, 6))
bars = plt.bar(top_5_configs, top_5_accuracies, color='skyblue')
plt.xlabel('Configuration')
plt.ylabel('Accuracy')
plt.title('Top 5 Configurations with Highest Accuracy')
plt.xticks(rotation=45, ha='right')
plt.ylim(0, 100)  # Setting y-axis limit from 0 to 100 for percentage
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adding text inside the bars
for bar, accuracy in zip(bars, top_5_accuracies):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() - 5, f'{accuracy:.2f}%',
             ha='center', va='bottom', color='black', fontsize=10)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Extract the configuration with the highest accuracy
best_config = max(FC_results, key=lambda x: x[5])

# Extract configuration parameters
config_name = best_config[0]
num_layers = best_config[1]
layer_sizes = sum(best_config[2])
batch_size = best_config[3]
learning_rate = best_config[4]
accuracy = best_config[5] * 100

# Create a bar plot for the configuration parameters
labels = ['Num Hidden Layers', 'Hidden Layer Sizes', 'Batch Size', 'Learning Rate']
values = [num_layers, layer_sizes, batch_size, learning_rate]

# Plot each parameter separately
fig, axs = plt.subplots(2, 2, figsize=(12, 12))
fig.suptitle(f"{config_name} (Accuracy: {accuracy:.2f}%)", fontsize=16)

for i, label in enumerate(labels):
    ax = axs[i//2][i%2]
    ax.bar(label, values[i], color='skyblue')
    ax.set_title(label)
    ax.set_ylabel('Values')

    # Annotate the bars with their corresponding values inside the bars
    ax.text(0.5, values[i], str(values[i]), color='black', va='center', ha='center')

plt.tight_layout()
plt.show()
